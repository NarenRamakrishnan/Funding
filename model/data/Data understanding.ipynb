# %%
import pandas as pd

# %%
df = pd.read_json('train.json') 
df
# Out:
#                                                 tokens  \
# 0    [Snowflake, closed, a, $30M, Series-A, funding...
# 1    [In, July-2024, HashiCorp, announced, a, $1.5B...
# 2    [Insight-Partners, and, Tiger-Global, co-led, ...
# 3    [OpenAI, raised, $15M, in, a, Series-B, round,...
# 4    [In, Q4-2024, Nubank, announced, a, $1.5B, Ser...
# ..                                                 ...
# 795  [In, a, Growth, round, Figma, raised, $300M, w...
# 796  [In, a, Series-F, round, Monzo, raised, $1B, w...
# 797  [Scale-AI, raised, $250M, in, a, Pre-Seed, rou...
# 798  [Spark-Capital, led, a, $250M, Series-C, inves...
# 799  [Coinbase, raised, $100M, in, a, Series-F, rou...
#
#                                    labels  \
# 0             [1, 0, 0, 2, 3, 0, 0, 0, 5]
# 1          [0, 5, 1, 0, 0, 2, 3, 0, 0, 4]
# 2          [4, 0, 4, 0, 1, 0, 2, 3, 0, 5]
# 3    [1, 0, 2, 0, 0, 3, 0, 0, 0, 4, 0, 5]
# 4          [0, 5, 1, 0, 0, 2, 3, 0, 0, 4]
# ..                                    ...
# ...

# %%
df.columns
# Out:
# Index(['tokens', 'labels', 'sentence'], dtype='object')

# %%
type(df.iloc[0]['tokens'])
# Out:
# list

# %%
df = df.loc[:,['labels','sentence']]
df
# Out:
#                                    labels  \
# 0             [1, 0, 0, 2, 3, 0, 0, 0, 5]
# 1          [0, 5, 1, 0, 0, 2, 3, 0, 0, 4]
# 2          [4, 0, 4, 0, 1, 0, 2, 3, 0, 5]
# 3    [1, 0, 2, 0, 0, 3, 0, 0, 0, 4, 0, 5]
# 4          [0, 5, 1, 0, 0, 2, 3, 0, 0, 4]
# ..                                    ...
# 795        [0, 0, 3, 0, 1, 0, 2, 0, 4, 0]
# 796        [0, 0, 3, 0, 1, 0, 2, 0, 4, 0]
# 797  [1, 0, 2, 0, 0, 3, 0, 0, 0, 4, 0, 5]
# 798        [4, 0, 0, 2, 3, 0, 0, 1, 0, 5]
# 799  [1, 0, 2, 0, 0, 3, 0, 0, 0, 4, 0, 5]
#
#                                               sentence
# 0    Snowflake closed a $30M Series-A funding round...
# 1    In July-2024 HashiCorp announced a $1.5B Serie...
# 2    Insight-Partners and Tiger-Global co-led Datab...
# 3    OpenAI raised $15M in a Series-B round led by ...
# 4    In Q4-2024 Nubank announced a $1.5B Series-A r...
# ..                                                 ...
# 795  In a Growth round Figma raised $300M with Khos...
# ...

# %%
df.to_json('train_edited.json', orient='records')
